# %% [markdown]
# <a href="https://colab.research.google.com/github/idrissdeme/Projetos-Python-IRD/blob/main/PROJETO_NEUTRONS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#MEMÓRIA DE CÁLCULO - NEUTRONS

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dfneutrons = pd.read_excel('/content/memoria_calculo V4.xlsx')

# %%
from google.colab import data_table

# %%
dfneutrons.head(190)
# Out:
#                                                MnSo4 Unnamed: 1 Unnamed: 2  \
# 0                                                NaN          1          2
# 1                                          cad vazio     10.397     10.473
# 2                                        cad solução    148.428    148.421
# 3                                        cad seco 1h     55.308     55.409
# 4                                  cad dessecado 24h     55.362     55.473
# ..                                               ...        ...        ...
# 178                             relação de  A base/A   2.416157        NaN
# 179                    relação de efic. base/  efic.   1.928014        NaN
# 180                                              NaN        NaN        NaN
# 181                                              NaN        NaN        NaN
# 182  aumento esperado na eficef. * (relacao A base/A   0.001339        NaN
#
#     Unnamed: 3   Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# ...

# %%
dfneutrons['Unnamed: 1'][110]
# Out:
# 0.02378423429992812

# %%
#DETERMINAÇÃO DE F
F=(dfneutrons['Unnamed: 1'][110]*(1+dfneutrons['Unnamed: 1'][114]))/((dfneutrons['Unnamed: 1'][110]*(1+dfneutrons['Unnamed: 1'][114]))+dfneutrons['Unnamed: 1'][109]+dfneutrons['Unnamed: 1'][111])
print(F)
# Out:
# 0.5295112927318654

# %%
dfneutrons['Unnamed: 1'][124]
# Out:
# 3.641871e-05

# %%
#DERTERMINAÇÃO DE K
#F=(dfneutrons['Unnamed: 1'][110]*(1+dfneutrons['Unnamed: 1'][114]))/((dfneutrons['Unnamed: 1'][110]*(1+dfneutrons['Unnamed: 1'][114]))+dfneutrons['Unnamed: 1'][109]+dfneutrons['Unnamed: 1'][111])
K= 1/(1-dfneutrons['Unnamed: 1'][124]-dfneutrons['Unnamed: 1'][125]-dfneutrons['Unnamed: 1'][126])
valor_esperado= 1.048690709649
erro = valor_esperado - K
print('O valor de K é', K, 'com um erro de', erro)
# Out:
# O valor de K é 1.0780606309552265 com um erro de -0.02936992130622662

# %%
import numpy as np

# %%
from numpy.core.fromnumeric import mean
#DETERMINAÇÃO DE A
#MÉDIA DA LINHA 147, DO B1 ATÉ B16(EXCEL)
A= mean(float(dfneutrons['Unnamed: 1'][145]))
print(A)
# Out:
# 583.2573447103347

# %%
#EFICIENCIA ESTIMADA
#(B149*B132)/(B171*B119)
Mi1994= dfneutrons['Unnamed: 1'][166]
Q1994= dfneutrons['Unnamed: 1'][167]
Diftempo= dfneutrons['Unnamed: 1'][168]
CD= dfneutrons['Unnamed: 1'][169]
print('Mi usado para 1994',Mi1994)
print('Valor de Q esperado em 1994 foi de',Q1994)
print('Diferença de Tempo em segundos',Diftempo)
print('Correção de Decaimento',CD)
E= dfneutrons['Unnamed: 1'][147]*dfneutrons['Unnamed: 1'][130]/dfneutrons['Unnamed: 1'][169]*dfneutrons['Unnamed: 1'][117]
print('Eficiência Estimada atual é',E)
# Out:
# Mi usado para 1994 5.08238e-11
# Valor de Q esperado em 1994 foi de 2217000
# Diferença de Tempo em segundos 896832000
# Correção de Decaimento 2118216.625827941
# Eficiência Estimada atual é 0.00015539431761347084

# %%
#TEMPO POR CONTAGEM

# %%
dfneutrons1 = dfneutrons = pd.read_excel('/content/drive/MyDrive/memoria_calculo V4.xlsx',sheet_name = 'Planilha2')
display(dfneutrons)
# Out:
#             Unnamed: 0     Tempo  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0  2018-10-24 12:02:27  12:02:27         1.0         0.0      542.20
# 1  2018-10-24 00:00:00  12:11:31         1.0         0.0      541.23
# 2  2018-10-24 00:00:00  12:20:33         1.0         0.0      540.03
# 3  2018-10-24 00:00:00  12:29:34         1.0         0.0      538.05
# 4  2018-10-24 00:00:00  12:38:34         1.0         0.0      536.64
# 5  2018-10-24 00:00:00  12:47:32         1.0         0.0      535.65
# 6  2018-10-24 00:00:00  12:56:29         1.0         0.0      534.06
# 7  2018-10-24 00:00:00  13:05:24         1.0         0.0      532.54
# 8  2018-10-24 00:00:00  13:14:18         1.0         0.0      531.25
# 9  2018-10-24 00:00:00  13:23:11         1.0         0.0      529.97
# 10 2018-10-24 00:00:00  13:32:02         1.0         0.0      528.80
# 11 2018-10-24 00:00:00  13:40:52         1.0         0.0      527.88
# 12 2018-10-24 00:00:00  13:49:41         1.0         0.0      526.64
# ...

# %%
import matplotlib.pyplot as plt 
#dfneutrons1['Tempo']['Contagem'].plot
dfneutrons1.plot(x='Tempo', y='Contagem', kind='line', color='blue')
plt.show()

# %% [markdown]
# # Nova seção
